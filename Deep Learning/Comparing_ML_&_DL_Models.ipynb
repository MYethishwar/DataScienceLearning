# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df =pd.read_csv('pima_india_diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
x = df.drop(['Outcome'], axis = 1)

y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x, y, random_state=90, test_size = 0.2)

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
modelRF = RandomForestClassifier(n_estimators=5)

modelRF.fit(x_train,y_train)
y_pred = modelRF.predict(x_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       105
#            1       0.61      0.63      0.62        49
#
#     accuracy                           0.75       154
#    macro avg       0.72      0.72      0.72       154
# weighted avg       0.76      0.75      0.75       154

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten,LeakyReLU

# %%
model = Sequential([
    Dense(128,input_dim=8,activation='relu'),
    Dense(64,activation=LeakyReLU(alpha=0.2)),
    Dense(32,activation=LeakyReLU(alpha=0.2)),
    Dense(16,activation=LeakyReLU(alpha=0.2)),
    Dense(1,activation='sigmoid'),
])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
model.fit(x_train,y_train, epochs=50,validation_data=(x_test , y_test))
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5705 - loss: 1.5032 - val_accuracy: 0.3506 - val_loss: 1.4299
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5452 - loss: 0.9907 - val_accuracy: 0.6364 - val_loss: 0.8994
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6316 - loss: 0.7048 - val_accuracy: 0.7078 - val_loss: 0.6255
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6521 - loss: 0.6518 - val_accuracy: 0.6623 - val_loss: 0.6024
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6954 - loss: 0.6129 - val_accuracy: 0.6104 - val_loss: 0.7190
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5855 - loss: 0.8339 - val_accuracy: 0.5844 - val_loss: 0.6913
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6059 - loss: 0.7964 - val_accuracy: 0.7013 - val_loss: 0.7607
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7030 - loss: 0.6365 - val_accuracy: 0.6883 - val_loss: 0.6027
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6871 - loss: 0.6185 - val_accuracy: 0.7078 - val_loss: 0.5821
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6661 - loss: 0.6215 - val_accuracy: 0.5455 - val_loss: 0.8235
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6220 - loss: 0.7016 - val_accuracy: 0.6104 - val_loss: 0.6887
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7110 - loss: 0.5906 - val_accuracy: 0.5974 - val_loss: 0.6468
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7349 - loss: 0.5529 - val_accuracy: 0.7078 - val_loss: 0.7043
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6955 - loss: 0.5701 - val_accuracy: 0.6169 - val_loss: 0.7074
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7059 - loss: 0.5937 - val_accuracy: 0.6039 - val_loss: 0.6839
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7233 - loss: 0.5567 - val_accuracy: 0.6948 - val_loss: 0.5586
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7114 - loss: 0.5632 - val_accuracy: 0.6623 - val_loss: 0.5689
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7617 - loss: 0.5184 - val_accuracy: 0.6688 - val_loss: 0.5782
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7407 - loss: 0.5578 - val_accuracy: 0.6623 - val_loss: 0.5580
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7325 - loss: 0.5775 - val_accuracy: 0.6818 - val_loss: 0.5675
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7288 - loss: 0.5270 - val_accuracy: 0.6948 - val_loss: 0.6276
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7170 - loss: 0.5382 - val_accuracy: 0.6948 - val_loss: 0.5833
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7319 - loss: 0.5414 - val_accuracy: 0.6623 - val_loss: 0.6442
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7353 - loss: 0.5499 - val_accuracy: 0.5779 - val_loss: 0.7808
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6980 - loss: 0.5772 - val_accuracy: 0.6818 - val_loss: 0.6533
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7196 - loss: 0.5362 - val_accuracy: 0.6948 - val_loss: 0.5717
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7482 - loss: 0.5611 - val_accuracy: 0.6818 - val_loss: 0.6649
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6745 - loss: 0.6807 - val_accuracy: 0.6688 - val_loss: 0.6369
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7577 - loss: 0.6187 - val_accuracy: 0.7143 - val_loss: 0.5894
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7333 - loss: 0.5334 - val_accuracy: 0.7013 - val_loss: 0.5622
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7359 - loss: 0.5210 - val_accuracy: 0.7013 - val_loss: 0.5563
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7493 - loss: 0.5134 - val_accuracy: 0.6753 - val_loss: 0.5793
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7675 - loss: 0.5045 - val_accuracy: 0.6818 - val_loss: 0.5470
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7647 - loss: 0.5097 - val_accuracy: 0.6623 - val_loss: 0.6553
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6949 - loss: 0.6090 - val_accuracy: 0.7338 - val_loss: 0.5489
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7350 - loss: 0.5172 - val_accuracy: 0.6818 - val_loss: 0.5509
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7503 - loss: 0.5171 - val_accuracy: 0.6753 - val_loss: 0.5443
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7472 - loss: 0.5146 - val_accuracy: 0.6948 - val_loss: 0.5770
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7822 - loss: 0.4749 - val_accuracy: 0.6948 - val_loss: 0.5550
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7523 - loss: 0.5364 - val_accuracy: 0.6299 - val_loss: 0.6869
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7057 - loss: 0.5908 - val_accuracy: 0.7208 - val_loss: 0.5743
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7268 - loss: 0.5498 - val_accuracy: 0.7208 - val_loss: 0.5625
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7442 - loss: 0.5065 - val_accuracy: 0.6818 - val_loss: 0.5831
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7432 - loss: 0.5001 - val_accuracy: 0.6948 - val_loss: 0.6221
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7225 - loss: 0.5762 - val_accuracy: 0.7013 - val_loss: 0.5542
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7826 - loss: 0.4641 - val_accuracy: 0.6883 - val_loss: 0.5907
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7282 - loss: 0.5538 - val_accuracy: 0.6688 - val_loss: 0.6025
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7249 - loss: 0.5489 - val_accuracy: 0.7143 - val_loss: 0.5397
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7198 - loss: 0.5867 - val_accuracy: 0.7338 - val_loss: 0.5523
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7482 - loss: 0.5352 - val_accuracy: 0.7208 - val_loss: 0.5793

# %%
x = model.evaluate(x_test,y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7233 - loss: 0.5687

# %%
data  = pd.read_csv('college_student_placement_dataset.csv')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['Placement'] = le.fit_transform(data['Placement'])
data['Internship_Experience'] = le.fit_transform(data['Internship_Experience'])

# %%
x = data.drop(['Placement','Prev_Sem_Result'], axis=1)
# We removed Prev_Sem_Result because there is much correlation between 'CGPA' and 'Prev_Sem_Result'
y = data['Placement']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 98, train_size=0.8 )

# %%
df2 = pd.read_csv('cancer patient data sets.csv')

# %%
df2.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
# 3            2                    3         1                      4
# 4            2                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High
#
# [5 rows x 26 columns]

# %%
print(df2.columns)
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
x = df2.drop(columns=['Level'], axis=1)
y = df2['Level']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test = train_test_split(x,y, random_state = 80, train_size = 0.8)

# %%
model = Sequential([
    Dense(128,input_dim=25,activation='relu'),
    Dense(64,activation='relu'),
    Dense(34,activation='relu'),
    Dense(16,activation='relu'),
    Dense(1,activation='softmax'),
])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x_train,y_train, epochs=50,validation_data=(x_test , y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-408322645.py in <cell line: 0>()
# ----> 1 model.fit(x_train,y_train, epochs=50,validation_data=(x_test , y_test))
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/optree/ops.py in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     764     leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     765     flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 766     return treespec.unflatten(map(func, *flat_args))
#     767
#     768
#
# ValueError: Invalid dtype: object
