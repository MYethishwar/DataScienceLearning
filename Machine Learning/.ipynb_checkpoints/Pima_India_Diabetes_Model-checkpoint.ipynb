# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/yathi/GitRepos/DataScienceLearning/DataSets/pima_india_diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# First Dealing with Missing values... represented in 0's 
# Where some are real zeros and others not
# Real zero features -> Pregnancies, DPF
# Non Real Zero features -> Glucose, BloodPressure, SkinThikness, Insulin, Age, BMI

# %%
# So replacing it with the median value

# %%
(data == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
median_G = data['Glucose'].median()
data['Glucose'] = data['Glucose'].replace(0, median_P)

# %%
median_B = data['BloodPressure'].median()
data['BloodPressure'] = data['BloodPressure'].replace(0, median_P)

# %%
median_S = data['SkinThickness'].median()
data['SkinThickness'] = data['SkinThickness'].replace(0, median_P)

# %%
median_B = data['BloodPressure'].median()
data['BloodPressure'] = data['BloodPressure'].replace(0, median_P)

# %%
median_B = data['Insulin'].median()
data['Insulin'] = data['Insulin'].replace(0, median_P)

# %%
median_BMI = data['BMI'].median()
data['BMI'] = data['BMI'].replace(0, median_P)

# %%
# checking for wrong data [Outliers]

# %%
# values which are rare and biologically impossible 
# pregnancies   -    > 10
# Glucose       -    >180
# BloodPressure -    <40, >110
# SkinThickness -    >50
# Insulin       -    >300
# BMI           -    >55
# DPF           -    >2.0
# Age           -    >100

# %%
(data['Age'] > 100).sum()
# Out:
# np.int64(0)

# %%
data[(data['DiabetesPedigreeFunction'] > 2.0) & (data['Insulin'] > 300)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 228            4      197             70             39      744  36.7
# 370            3      173             82             48      465  38.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 228                     2.329   31        0
# 370                     2.137   25        1

# %%
# Dealing with duplicated values
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# When do we need normalization, is there any specific algorithm which needs normalization or else we need to do it for all

# %%
 x = data.drop('Outcome', axis = 1)
y = data['Outcome']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x, y, random_state=91)

# %%
y_train.value_counts()
# Out:
# Outcome
# 0    369
# 1    207
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_train, y_train = smote.fit_resample(x_train, y_train)

# %%
y_train.value_counts()
# Out:
# Outcome
# 1    369
# 0    369
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
modelDT = DecisionTreeClassifier()

modelDT.fit(x_train,y_train)
y_pred = modelDT.predict(x_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.81      0.73       107
#            1       0.67      0.48      0.56        85
#
#     accuracy                           0.67       192
#    macro avg       0.67      0.65      0.65       192
# weighted avg       0.67      0.67      0.66       192

# %%
from sklearn.ensemble import RandomForestClassifier
modelRF = RandomForestClassifier(n_estimators=5)

modelRF.fit(x_train,y_train)
y_pred = modelRF.predict(x_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.82      0.72       104
#            1       0.69      0.48      0.56        88
#
#     accuracy                           0.66       192
#    macro avg       0.67      0.65      0.64       192
# weighted avg       0.67      0.66      0.65       192

# %%
from sklearn.linear_model import LogisticRegression
modelLR = LogisticRegression()

modelLR.fit(x_train,y_train)
y_pred = modelLR.predict(x_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.88      0.77       104
#            1       0.79      0.55      0.64        88
#
#     accuracy                           0.72       192
#    macro avg       0.74      0.71      0.71       192
# weighted avg       0.74      0.72      0.71       192
# C:\Users\yathi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
