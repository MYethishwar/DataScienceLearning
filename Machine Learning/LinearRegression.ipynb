# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
df = {
    'BedRooms':[1,2,3,4,5],
    'RentPrice':[10000,12000,15000,30000, 40000]
}
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    BedRooms  RentPrice
# 0         1      10000
# 1         2      12000
# 2         3      15000
# 3         4      30000
# 4         5      40000

# %%
import seaborn as sns
sns.scatterplot(data=df, x = 'BedRooms', y = 'RentPrice')
# Out:
# <Axes: xlabel='BedRooms', ylabel='RentPrice'>

# %%
df.corr()
# Out:
#            BedRooms  RentPrice
# BedRooms   1.000000   0.946446
# RentPrice  0.946446   1.000000

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x = df[['BedRooms']]
y = df['RentPrice']

model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[6]])
# Out:
# C:\Users\yathi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44800.])

# %%
m = model.coef_
m
# Out:
# array([7800.])

# %%
c = model.intercept_
c
# Out:
# np.float64(-2000.0000000000073)

# %%
def prediction(x):
  return (m*x)+c

prediction(9)
# Out:
# array([68200.])

# %%
# Multiple Linear Regression
df = {
    'Bedrooms':[1,2,3,4,5],
    'Bathrooms':[1,1,2,2,3],
    'Area':[800,1000,1400,1600,1700],
    'RentPrice':[10000,12000,15000,20000,25000]
}

df = pd.DataFrame(df)
df.head()
# Out:
#    Bedrooms  Bathrooms  Area  RentPrice
# 0         1          1   800      10000
# 1         2          1  1000      12000
# 2         3          2  1400      15000
# 3         4          2  1600      20000
# 4         5          3  1700      25000

# %%
x = df[['Bedrooms','Bathrooms','Area']]
y = df['RentPrice']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[1,1,1000]])
# Out:
# C:\Users\yathi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7416.66666667])

# %%
m1,m2,m3 = model.coef_
c = model.intercept_

# %%
def predictMLR(x1,x2,x3):
  return ((m1*x1)+(m2*x2)+(m3*x3)+c)

predictMLR(1,1,1500)
# Out:
# np.float64(2833.3333333330465)

# %%
data = pd.read_csv("C:/Users/yathi/GitRepos/DataScienceLearning/DataSets/placement.csv")

# %%
data.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
data.shape
# Out:
# (200, 2)

# %%
x = data[['cgpa']]
y = data['package']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[9]])
# Out:
# C:\Users\yathi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.14064371])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=43,test_size=0.20)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
x_test.head()
# Out:
#     cgpa
# 56  5.84
# 37  5.90
# 67  6.51
# 79  7.18
# 80  7.63

# %%
sns.boxplot(data['package'])
# Out:
# <Axes: ylabel='package'>

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_test.head()
# Out:
# 56    2.74
# 37    2.43
# 67    2.89
# 79    3.00
# 80    3.44
# Name: package, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_pred,y_test))
# Out:
# 0.25741183576582627

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6)) 
plt.scatter(x, y, color='blue', label='Data Points') 
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Regression Line') 
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
