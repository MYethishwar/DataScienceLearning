# %%
with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt') as fp:
    print(fp.readline())
# Out:
# Hi, Hello

# %%
with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt') as fp:
    for i in fp.readlines():
        print(i)
# Out:
# Hey i just borned now... make my birthday

# %%
# Writing a file by passing operads to the ending... 
# 'a' used to append the content to the ending of the text
# 'w' used to overwrite the existing text inside the file
with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt','a') as fp:
    fp.write("There is a new line added...")

# %%
with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt') as fp:
    for i in fp.readlines():
        print(i)
# Out:
# Hey i just borned now... make my birthdayThere is a new line added...

# %%
# using 'w' can over written all the text inside the file 
with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt','w') as fp:
    fp.write("I completly eaten text inside the file")

# %%
with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt') as fp:
    for i in fp.readlines():
        print(i)
# Out:
# I completly eaten text inside the file

# %%
# Creating  new file in python
# 'x' creates a file, returns an error if file already exists
# 'a' creates a file, if the specified file doesnot exists
# 'w' creates a file, if the specified file doesnot exists

# with open(r'C:\Users\yathi\OneDrive\Desktop\sample.txt','x') as fp:
#     fp.write("Hi")

with open(r'C:\Users\yathi\OneDrive\Desktop\sample1.txt','w') as fp:
    fp.write("Hey i just borned now... make my birthday")

# %%
# Created new file where sample1 are not exist before
with open(r'C:\Users\yathi\OneDrive\Desktop\sample1.txt') as fp:
    for i in fp.readlines():
        print(i)
# Out:
# Hey i just borned now... make my birthday

# %%
# To delete a file 
# use os.remove() function by importing it in to our code
# import os

# if os.path.exists('C:/Users/yathi/OneDrive/Desktop/sample1.txt'):
#     os.remove('C:/Users/yathi/OneDrive/Desktop/sample1.txt')
#     print("File deleted successfully")
# else:
#     print("The file does not exist")
